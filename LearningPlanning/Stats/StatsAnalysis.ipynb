# %%
import os
import csv
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from plot_func import *

# %%
files = [
    "stats_Random.csv",
    "stats_IRALe.csv",
    "stats_Revision_Probability.csv",
    "stats_Revision_Probability_Meta.csv"
]

# %%
plot_category("blocksworld", files)
# Out:
# Error loading: blocksworld/stats_Revision_Probability.csv
# No handles with labels found to put in legend.

# %%
plot_category("colorblocksworld", files, allfiles=True, drawregions=True, step=1, dense=False)
# Out:
# Error loading: colorblocksworld/stats_Random.csv
# Error loading: colorblocksworld/stats_IRALe.csv
# Error loading: colorblocksworld/stats_Revision_Probability.csv
# Error loading: colorblocksworld/stats_Revision_Probability_Meta.csv

# %%
plot_category("colorblocksworld_antistagnation", files, allfiles=True, drawregions=False)
# Out:
# Error loading: colorblocksworld_antistagnation/stats_Revision_Probability_Meta.csv

# %%
plot_category("noheadstart", files, step=1, drawregions=False, dense=True)

# %%
plot_category("longruns", files, drawregions=False, step=5, dense=False)

# %%
from merge_data import *

# %%
merge_files("colorblocksworld/", "stats_Revision_Probability_ANY_newalg.csv",
            ["stats_Revision_Probability_ANY_1.csv",
             "stats_Revision_Probability_ANY_2.csv",
             "stats_Revision_Probability_ANY_3.csv",
             "stats_Revision_Probability_ANY_4.csv"])

# %%
merge_files("colorblocksworld/", "stats_Revision_Probability_LGG_genonly.csv",
            ["stats_Revision_Probability_LGG_1.csv",
             "stats_Revision_Probability_LGG_2.csv",
             "stats_Revision_Probability_LGG_3.csv",
             "stats_Revision_Probability_LGG_4.csv"])

# %%
merge_files("colorblocksworld/", "stats_IRALe_ANY_stagn.csv",
            ["stats_IRALe_ANY_1.csv",
             "stats_IRALe_ANY_2.csv"])
merge_files("colorblocksworld/", "stats_Random_ANY_stagn.csv",
            ["stats_Random_ANY_1.csv",
             "stats_Random_ANY_2.csv"])
